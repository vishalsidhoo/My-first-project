# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalsidhoo/My-first-project/blob/main/Ecommerce_Data_Anlaysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Ecommerce_Consumer_Behavior_Analysis_Data.csv')

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category Purchase_Amount  ...  \
# ...

# %%
# Show Top 3 Record from datasets
df.head(3)
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0  37-611-6911   22  Female       Middle        Married      Bachelor's
# 1  29-392-9296   49    Male         High        Married     High School
# 2  84-649-5117   24  Female       Middle         Single        Master's
#
#   Occupation  Location     Purchase_Category Purchase_Amount  ...  \
# 0     Middle      Évry  Gardening & Outdoors        $333.80   ...
# 1       High  Huocheng      Food & Beverages        $222.22   ...
# 2       High    Huzhen       Office Supplies        $426.22   ...
#
#    Customer_Satisfaction Engagement_with_Ads  Device_Used_for_Shopping  \
# 0                      7                 NaN                    Tablet
# 1                      5                High                    Tablet
# 2                      7                 Low                Smartphone
#
#    Payment_Method  Time_of_Purchase Discount_Used  \
# 0     Credit Card          3/1/2024          True
# ...

# %%
# How Many record are present in our dataset
df.shape
# Out:
# (1000, 28)

# %%
# Calculate Stataical
df.describe()
# Out:
#                Age  Frequency_of_Purchase  Brand_Loyalty  Product_Rating  \
# count  1000.000000            1000.000000    1000.000000     1000.000000
# mean     34.304000               6.945000       3.026000        3.033000
# std       9.353238               3.147361       1.416803        1.436654
# min      18.000000               2.000000       1.000000        1.000000
# 25%      26.000000               4.000000       2.000000        2.000000
# 50%      34.500000               7.000000       3.000000        3.000000
# 75%      42.000000              10.000000       4.000000        4.000000
# max      50.000000              12.000000       5.000000        5.000000
#
#        Time_Spent_on_Product_Research(hours)  Return_Rate  \
# count                            1000.000000  1000.000000
# mean                                1.013030     0.954000
# std                                 0.791802     0.810272
# min                                 0.000000     0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Customer_ID                            1000 non-null   object
#  1   Age                                    1000 non-null   int64
#  2   Gender                                 1000 non-null   object
#  3   Income_Level                           1000 non-null   object
#  4   Marital_Status                         1000 non-null   object
#  5   Education_Level                        1000 non-null   object
#  6   Occupation                             1000 non-null   object
#  7   Location                               1000 non-null   object
#  8   Purchase_Category                      1000 non-null   object
#  9   Purchase_Amount                        1000 non-null   object
# ...

# %%
# Check How Many Null Values Present In Our Datasets
df.isnull().sum()
# Out:
# Customer_ID                                0
# Age                                        0
# Gender                                     0
# Income_Level                               0
# Marital_Status                             0
# Education_Level                            0
# Occupation                                 0
# Location                                   0
# Purchase_Category                          0
# Purchase_Amount                            0
# Frequency_of_Purchase                      0
# Purchase_Channel                           0
# Brand_Loyalty                              0
# Product_Rating                             0
# Time_Spent_on_Product_Research(hours)      0
# Social_Media_Influence                   247
# Discount_Sensitivity                       0
# Return_Rate                                0
# Customer_Satisfaction                      0
# Engagement_with_Ads                      256
# Device_Used_for_Shopping                   0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# Show Null Values Through Heatmap
sns.heatmap(df.isnull())
plt.show()

# %%
df['Social_Media_Influence'].isnull().sum()
# Out:
# np.int64(247)

# %%
df['Social_Media_Influence']
# Out:
# 0        High
# 1      Medium
# 2         Low
# 3        High
# 4      Medium
#         ...
# 995      High
# 996       Low
# 997       Low
# 998       Low
# 999    Medium
# Name: Social_Media_Influence, Length: 1000, dtype: object

# %%
# Find Mode Of This Categorical Values
df['Social_Media_Influence'].mode()
df['Social_Media_Influence'].fillna(df['Social_Media_Influence'].mode()[0],inplace=True)

# %%
df['Engagement_with_Ads'].isnull().sum()
# Out:
# np.int64(256)

# %%
df['Engagement_with_Ads']
# Out:
# 0        High
# 1        High
# 2         Low
# 3        High
# 4        High
#         ...
# 995      High
# 996       Low
# 997      High
# 998    Medium
# 999       Low
# Name: Engagement_with_Ads, Length: 1000, dtype: object

# %%
# Find Mode OF This Columns
df['Engagement_with_Ads'].mode()
df['Engagement_with_Ads'].fillna(df['Engagement_with_Ads'].mode()[0],inplace=True)

# %%
# Check Data Types Of This Datasets
df.dtypes
# Out:
# Customer_ID                               object
# Age                                        int64
# Gender                                    object
# Income_Level                              object
# Marital_Status                            object
# Education_Level                           object
# Occupation                                object
# Location                                  object
# Purchase_Category                         object
# Purchase_Amount                           object
# Frequency_of_Purchase                      int64
# Purchase_Channel                          object
# Brand_Loyalty                              int64
# Product_Rating                             int64
# Time_Spent_on_Product_Research(hours)    float64
# Social_Media_Influence                    object
# Discount_Sensitivity                      object
# Return_Rate                                int64
# Customer_Satisfaction                      int64
# ...

# %%
df['Customer_ID']=df['Customer_ID'].replace('-','',regex=True)

# %%
df['Customer_ID']
# Out:
# 0      376116911
# 1      293929296
# 2      846495117
# 3      489806078
# 4      911709072
#          ...
# 995    205622569
# 996    413664205
# 997    772417621
# 998    530912176
# 999    482039118
# Name: Customer_ID, Length: 1000, dtype: object

# %%
df['Customer_ID']=df['Customer_ID'].astype(int)

# %%
df['Purchase_Amount']
# Out:
# 0      $333.80
# 1      $222.22
# 2      $426.22
# 3      $101.31
# 4      $211.70
#          ...
# 995    $463.67
# 996     $69.78
# 997    $453.37
# 998    $106.15
# 999    $378.47
# Name: Purchase_Amount, Length: 1000, dtype: object

# %%
df['Purchase_Amount'] = df['Purchase_Amount'].str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(float)
df['Purchase_Amount'] = df['Purchase_Amount'].astype(int)

# %%
df['Time_of_Purchase'] = pd.to_datetime(df['Time_of_Purchase'])

# %%
df["Month"]=df['Time_of_Purchase'].dt.month
df["Year"]=df['Time_of_Purchase'].dt.year
df["Day_Name"]=df['Time_of_Purchase'].dt.day_name()
df["Day"]=df['Time_of_Purchase'].dt.day

# %%
df.head(3)
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    376116911   22  Female       Middle        Married      Bachelor's
# 1    293929296   49    Male         High        Married     High School
# 2    846495117   24  Female       Middle         Single        Master's
#
#   Occupation  Location     Purchase_Category  Purchase_Amount  ...  \
# 0     Middle      Évry  Gardening & Outdoors              333  ...
# 1       High  Huocheng      Food & Beverages              222  ...
# 2       High    Huzhen       Office Supplies              426  ...
#
#    Time_of_Purchase Discount_Used  Customer_Loyalty_Program_Member  \
# 0        2024-03-01          True                            False
# 1        2024-04-16          True                            False
# 2        2024-03-15          True                             True
#
#    Purchase_Intent  Shipping_Preference Time_to_Decision Month  Year  \
# ...

# %%
# Calculate Total Amount Purchase Gender Wise
df.groupby('Gender')['Purchase_Amount'].sum()
# Out:
# Gender
# Agender          4623
# Bigender         5159
# Female         127278
# Genderfluid      5010
# Genderqueer      3349
# Male           119930
# Non-binary       4597
# Polygender       4615
# Name: Purchase_Amount, dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.barplot(x='Gender',y='Purchase_Amount',data=df,palette="viridis")
# Add labels and title
plt.xlabel("Gender")
plt.ylabel("Total Purchase Amount")
plt.title("Total Purchase Amount by Gender")
plt.show()
# Out:
# <ipython-input-41-577a5bdb1dd5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender',y='Purchase_Amount',data=df,palette="viridis")

# %%
df["Customer_ID"].groupby(df["Gender"]).count()
# Out:
# Gender
# Agender         19
# Bigender        20
# Female         452
# Genderfluid     17
# Genderqueer     12
# Male           449
# Non-binary      16
# Polygender      15
# Name: Customer_ID, dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.countplot(x='Gender',data=df, palette="viridis")

plt.xlabel("Gender")
plt.ylabel("Total Employee")
plt.title("Total Employee Gender Wise")
plt.show()
# Out:
# <ipython-input-58-defa0210b7ac>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender',data=df, palette="viridis")

# %%
df.groupby('Marital_Status')['Purchase_Amount'].sum()
# Out:
# Marital_Status
# Divorced    67139
# Married     70853
# Single      66801
# Widowed     69768
# Name: Purchase_Amount, dtype: int64

# %%
sns.barplot(x='Marital_Status',y='Purchase_Amount',data=df,palette="viridis")
plt.xlabel("Marital_Status")
plt.ylabel("Total Purchase Amount")
plt.title("Total Purchase Amount by Marital_Status")
plt.show()
# Out:
# <ipython-input-60-066bdc93c1dc>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Marital_Status',y='Purchase_Amount',data=df,palette="viridis")

# %%
df['Purchase_Category'].unique()
# Out:
# array(['Gardening & Outdoors', 'Food & Beverages', 'Office Supplies',
#        'Home Appliances', 'Furniture', 'Books', 'Sports & Outdoors',
#        'Mobile Accessories', 'Luxury Goods', 'Animal Feed', 'Health Care',
#        'Hotels', 'Packages)', 'Electronics', 'Software & Apps',
#        'Baby Products', 'Toys & Games', 'Arts & Crafts',
#        'Health Supplements', 'Groceries', 'Clothing',
#        'Beauty & Personal Care', 'Travel & Leisure (Flights',
#        'Jewelry & Accessories'], dtype=object)

# %%
df['Purchase_Amount'].groupby(df['Income_Level']).sum()
# Out:
# Income_Level
# High      141625
# Middle    132936
# Name: Purchase_Amount, dtype: int64

# %%
sns.boxplot(x='Income_Level',y='Purchase_Amount',data=df,palette="viridis")
plt.xlabel("Income Leval")
plt.ylabel("Purchase Amount")
plt.title("Income levlas Vs Purchase Amount")
plt.show()
# Out:
# <ipython-input-63-5a427b8ea7aa>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Income_Level',y='Purchase_Amount',data=df,palette="viridis")

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0      376116911   22  Female       Middle        Married      Bachelor's
# 1      293929296   49    Male         High        Married     High School
# 2      846495117   24  Female       Middle         Single        Master's
# 3      489806078   29  Female       Middle         Single        Master's
# 4      911709072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995    205622569   44  Female         High       Divorced      Bachelor's
# 996    413664205   50  Female         High         Single     High School
# 997    772417621   26    Male         High        Married      Bachelor's
# 998    530912176   21  Female         High        Widowed      Bachelor's
# 999    482039118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category  Purchase_Amount  ...  \
# ...

# %%
payment=df.groupby('Payment_Method')['Purchase_Amount'].sum()

# %%
shipping=df.groupby("Shipping_Preference")['Purchase_Amount'].sum()

# %%
plt.figure(figsize=(6,6))
plt.pie(shipping,labels=shipping.index,autopct='%1.2f%%')
plt.title('Payment Method')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
intent=df.groupby("Purchase_Intent")["Purchase_Amount"].sum()

# %%
intent
# Out:
# Purchase_Intent
# Impulsive      63573
# Need-based     71763
# Planned        66648
# Wants-based    72577
# Name: Purchase_Amount, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.pie(intent,labels=intent.index,autopct='%1.2f%%')
plt.title('Payment Method')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %%
# Pie Plot
plt.figure(figsize=(6,6))
plt.pie(payment,labels=payment.index,autopct='%1.2f%%')
plt.title('Payment Method')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
Day=df.groupby(['Day_Name'])['Purchase_Amount'].sum()

# %%
Day
# Out:
# Day_Name
# Friday       36215
# Monday       41334
# Saturday     34024
# Sunday       41770
# Thursday     42248
# Tuesday      44170
# Wednesday    34800
# Name: Purchase_Amount, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=Day.index,y=Day.values,palette="viridis")
plt.xlabel("Day Name")
plt.ylabel("Total Purchase Amount(In USD $ Dollars)")
plt.title("Total Purchase Amount by Day Name")
plt.show()
# Out:
# <ipython-input-116-9805bf9c134a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Day.index,y=Day.values,palette="viridis")

# %%
df.head(3)
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    376116911   22  Female       Middle        Married      Bachelor's
# 1    293929296   49    Male         High        Married     High School
# 2    846495117   24  Female       Middle         Single        Master's
#
#   Occupation  Location     Purchase_Category  Purchase_Amount  ...  \
# 0     Middle      Évry  Gardening & Outdoors              333  ...
# 1       High  Huocheng      Food & Beverages              222  ...
# 2       High    Huzhen       Office Supplies              426  ...
#
#    Time_of_Purchase Discount_Used  Customer_Loyalty_Program_Member  \
# 0        2024-03-01          True                            False
# 1        2024-04-16          True                            False
# 2        2024-03-15          True                             True
#
#    Purchase_Intent  Shipping_Preference Time_to_Decision Month  Year  \
# ...

# %%
df[(df['Age'] > 25) & (df['Salary'] > 50000)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Customer_ID                            1000 non-null   int64
#  1   Age                                    1000 non-null   int64
#  2   Gender                                 1000 non-null   object
#  3   Income_Level                           1000 non-null   object
#  4   Marital_Status                         1000 non-null   object
#  5   Education_Level                        1000 non-null   object
#  6   Occupation                             1000 non-null   object
#  7   Location                               1000 non-null   object
#  8   Purchase_Category                      1000 non-null   object
#  9   Purchase_Amount                        1000 non-null   int64
# ...

# %% [markdown]
# # Most Poupular Purchase Category

# %%
popular_category = df["Purchase_Category"].value_counts().idxmax()

# %%
popular_category
# Out:
# 'Electronics'

# %% [markdown]
# # Preferred Shopping Channel (Online Vs Offline)

# %%
# 4. Preferred shopping channel (Online vs. Offline)
df["Purchase_Channel"].value_counts()
# Out:
# Purchase_Channel
# Mixed       340
# Online      334
# In-Store    326
# Name: count, dtype: int64

# %%
# 9. Most Purchased Day of the Week
df["Day_Name"].value_counts().idxmax()
# Out:
# 'Tuesday'

# %% [markdown]
# # Monthly Trending Spending

# %%
# 10. Monthly Spending Trend
month=df.groupby("Month")["Purchase_Amount"].sum()

# %%
month
# Out:
# Month
# 1     19051
# 2     20256
# 3     27362
# 4     28567
# 5     18621
# 6     25211
# 7     25216
# 8     27427
# 9     24012
# 10    19454
# 11    21561
# 12    17823
# Name: Purchase_Amount, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=month.index,y=month.values,palette="viridis")
plt.xlabel("Month")
plt.ylabel("Total Purchase Amount")
plt.title("Total Purchase Amount by Month")
plt.show()
# Out:
# <ipython-input-53-9463d9a6d3e2>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=month.index,y=month.values,palette="viridis")

# %% [markdown]
# # How Many Total Amount Purchase By Week Day Name

# %%
week=df.groupby("Day_Name")["Purchase_Amount"].sum()

# %%
week
# Out:
# Day_Name
# Friday       36215
# Monday       41334
# Saturday     34024
# Sunday       41770
# Thursday     42248
# Tuesday      44170
# Wednesday    34800
# Name: Purchase_Amount, dtype: int64

# %%
plt.figure(figsize=(10, 4))
sns.barplot(x=week.index,y=week.values,palette="viridis")
plt.xlabel("Day Name")
plt.ylabel("Total Purchase Amount")
plt.title("Total Purchase Amount(Amount In USD $) by Day Name")
plt.show()
# Out:
# <ipython-input-62-0a32769e1bb6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=week.index,y=week.values,palette="viridis")

# %%
high_value_customers = df[
    (df['Purchase_Amount'] > df['Purchase_Amount'].quantile(0.8)) &
    (df['Brand_Loyalty'] > 7) &
    (df['Frequency_of_Purchase'] > 10)
]

print("Total High-Value Customers:", high_value_customers.shape[0])
# Out:
# Total High-Value Customers: 0

# %% [markdown]
# If weekend sales are higher, running weekend flash sales could be a smart strategy.

# %%
weekend_sales = df[df['Day_Name'].isin(['Saturday', 'Sunday'])]['Purchase_Amount'].sum()
weekday_sales = df[~df['Day_Name'].isin(['Saturday', 'Sunday'])]['Purchase_Amount'].sum()

print("Weekend Sales:", weekend_sales)
print("Weekday Sales:", weekday_sales)
# Out:
# Weekend Sales: 75794
# Weekday Sales: 198767

# %% [markdown]
# # Which payment method is used most frequently for high-value purchases?

# %%
top_payment_method = df.groupby('Payment_Method')['Purchase_Amount'].sum().idxmax()
print("Most Preferred Payment Method:", top_payment_method)
# Out:
# Most Preferred Payment Method: PayPal

# %% [markdown]
# # Do Customer Influenced By Socia; Media Spend More

# %%
social_media_influenced = df[df['Social_Media_Influence'] == 'High']['Purchase_Amount'].mean()
not_social_media_influenced = df[df['Social_Media_Influence'] == 'Low']['Purchase_Amount'].mean()

print("Avg Spend (Social Media Influenced):", social_media_influenced)
print("Avg Spend (Not Social Media Influenced):", not_social_media_influenced)
# Out:
# Avg Spend (Social Media Influenced): 273.4796116504854
# Avg Spend (Not Social Media Influenced): 271.9879518072289

# %% [markdown]
# Do customers with low satisfaction have a higher return rate?
#
# # Do Customer With Low Satifaction Have A Higer Return Rate

# %%
return_rate_high_satisfaction = df[df['Customer_Satisfaction'] > 7]['Return_Rate'].mean()
return_rate_low_satisfaction = df[df['Customer_Satisfaction'] < 4]['Return_Rate'].mean()

print("Return Rate (High Satisfaction):", return_rate_high_satisfaction)
print("Return Rate (Low Satisfaction):", return_rate_low_satisfaction)
# Out:
# Return Rate (High Satisfaction): 0.9550173010380623
# Return Rate (Low Satisfaction): 0.9714285714285714

# %%
top_device = df['Device_Used_for_Shopping'].value_counts().idxmax()
print("Most Used Device:", top_device)
# Out:
# Most Used Device: Desktop

# %%
df.head(1)
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    376116911   22  Female       Middle        Married      Bachelor's
#
#   Occupation Location     Purchase_Category  Purchase_Amount  ...  \
# 0     Middle     Évry  Gardening & Outdoors              333  ...
#
#    Time_of_Purchase Discount_Used  Customer_Loyalty_Program_Member  \
# 0        2024-03-01          True                            False
#
#    Purchase_Intent  Shipping_Preference Time_to_Decision Month  Year  \
# 0       Need-based        No Preference                2     3  2024
#
#    Day_Name Day
# 0    Friday   1
#
# [1 rows x 32 columns]

# %%
# 2. Frequent Buyers vs. Return Rate
plt.figure(figsize=(8,5))
sns.barplot(x=df["Return_Rate"], y=df["Frequency_of_Purchase"], ci=None, palette="viridis")
plt.title("Frequent Buyers vs. Return Rate")
plt.xlabel("Return Rate")
plt.ylabel("Purchase Frequency")
plt.show()
# Out:
# <ipython-input-8-8dcd90018481>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["Return_Rate"], y=df["Frequency_of_Purchase"], ci=None, palette="viridis")
# <ipython-input-8-8dcd90018481>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["Return_Rate"], y=df["Frequency_of_Purchase"], ci=None, palette="viridis")

# %%
# 4. Ads Engagement vs. Purchase Intent
plt.figure(figsize=(10,5))
ads_vs_intent = pd.crosstab(df["Engagement_with_Ads"], df["Purchase_Intent"])
sns.heatmap(ads_vs_intent, annot=True, cmap="Blues", fmt="d")
plt.title("Ads Engagement vs. Purchase Intent")
plt.xlabel("Purchase Intent")
plt.ylabel("Engagement with Ads")
plt.show()

# %% [markdown]
# # Purchase Amount Acoording To Shipping Preferance

# %%
shipping=df.groupby("Shipping_Preference")["Purchase_Amount"].sum()

# %%
shipping
# Out:
# Shipping_Preference
# Express           81630
# No Preference    103419
# Standard          89512
# Name: Purchase_Amount, dtype: int64

# %%
plt.pie(shipping,labels=shipping.index,autopct='%1.2f%%')
plt.title('Shipping Preferance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# # Education Level Vs Purchases Amount

# %%
df.groupby("Education_Level")["Purchase_Amount"].sum()
# Out:
# Education_Level
# Bachelor's     96613
# High School    90598
# Master's       87350
# Name: Purchase_Amount, dtype: int64

# %%
### 4️⃣ Discounts vs. Spending ###
plt.figure(figsize=(8,5))
sns.boxplot(x=df["Discount_Sensitivity"], y=df["Purchase_Amount"], palette="viridis")
plt.title("Effect of Discounts on Spending")
plt.xlabel("Discount Sensitivity")
plt.ylabel("Purchase Amount")
plt.show()
# Out:
# <ipython-input-80-a35580582020>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["Discount_Sensitivity"], y=df["Purchase_Amount"], palette="viridis")

# %% [markdown]
# # Online Vs Offline Purchase

# %%
plt.figure(figsize=(6,2))
sns.countplot(x=df["Purchase_Channel"], palette="Set2")
plt.title("Preferred Shopping Channel (Online vs. Offline)")
plt.xlabel("Purchase Channel")
plt.ylabel("Number of Purchases")
plt.show()
# Out:
# <ipython-input-83-82c13ba8e6b9>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Purchase_Channel"], palette="Set2")

# %% [markdown]
# [link text](https://)

# %% [markdown]
# 🔹 Top Spenders:
# → High-value customers tend to be middle-aged professionals with high income levels. Businesses should target these customers with personalized offers.
#
# 🔹 Brand Loyalty Impact:
# → Customers with higher brand loyalty scores spend more. Investing in a loyalty program can increase customer retention.
#
# 🔹 Best Marketing Time:
# → Most purchases happen between 6 PM - 9 PM and on weekends.
# → Ideal time for marketing ads & promotions.
#
# 🔹 Discount Sensitivity:
# → Discount-sensitive customers tend to spend less per purchase but buy more frequently.
# → Offer targeted discounts to increase total spending.
#
# 🔹 Shopping Channel Preferences:
# → Customers prefer Online shopping over Offline. Businesses should focus on digital marketing & improve online platfor

# %% [markdown]
# Top Spender Ananlysis

# %%
plt.figure(figsize=(10,3))
top_spenders = df.groupby("Customer_ID")["Purchase_Amount"].sum().nlargest(10)
top_spenders.plot(kind="bar", color="green",width=0.6,edgecolor="red",linewidth=2)
plt.title("Top 10 High-Value Customers")
plt.xlabel("Customer ID")
plt.ylabel("Total Purchase Amount")
plt.show()

# %% [markdown]
# # Top 20 High Selling Products Vs Purchase Amount

# %%
plt.figure(figsize=(10,3))
top_spenders = df.groupby("Purchase_Category")["Purchase_Amount"].sum().nlargest(20)
top_spenders.plot(kind="bar", color="red",width=0.6,edgecolor="green",linewidth=2)
plt.title("Top 20 High Selling Products")
plt.xlabel("Purchase Category")
plt.ylabel("Total Purchase Amount")
plt.show()

# %% [markdown]
# # Location Vs Purchase Amount

# %%
# @title Default title text
me = 0 # @param {"type":"slider","min":0,"max":100,"step":1}
plt.figure(figsize=(15,4))
top_spenders = df.groupby("Location")["Purchase_Amount"].sum().nlargest(25)
top_spenders.plot(kind="bar", color="blue",width=0.8,edgecolor="red",linewidth=2)
plt.title("Location Vs Purchase Amount In USD")
plt.xlabel("Location")
plt.ylabel("Total Purchase Amount")
plt.show()

# %%
df.groupby(["Location", "Purchase_Category"])["Purchase_Amount"].sum().nlargest(25)
# Out:
# Location         Purchase_Category
# Longotea         Sports & Outdoors        498
# Malasin          Gardening & Outdoors     498
# Nanqiao          Books                    497
# Tanahmerah       Jewelry & Accessories    497
# Wādī as Salqā    Gardening & Outdoors     497
# Cipolletti       Jewelry & Accessories    496
# Saltpond         Gardening & Outdoors     495
# San Nicolas      Health Care              495
# Acobambilla      Hotels                   494
# Muff             Software & Apps          494
# Oguma            Furniture                494
# Ābdānān          Home Appliances          494
# Cibeusi          Animal Feed              492
# Cimara           Health Care              492
# San Carlos       Health Care              492
# Negeriagung      Groceries                491
# Santa Marta      Furniture                491
# Sobinka          Clothing                 491
# Ḩabīl al Jabr    Luxury Goods             491
# Faqqū‘ah         Health Care              490
# ...

# %% [markdown]
# # Total Sales Location And Purchase Category Wise

# %%
plt.figure(figsize=(11,4))
top_Product =df.groupby(["Location", "Purchase_Category"])["Purchase_Amount"].sum().nlargest(15)
top_Product.plot(kind="bar", color="pink",width=0.6,edgecolor="blue",linewidth=2)
plt.title("Location,Purchase Category Vs Purchase Amount In USD")
plt.xlabel("Location And Purchase CAtegory")
plt.ylabel("Total Purchase Amount")
plt.show()

# %%
df.head(1)
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    376116911   22  Female       Middle        Married      Bachelor's
#
#   Occupation Location     Purchase_Category  Purchase_Amount  ...  \
# 0     Middle     Évry  Gardening & Outdoors              333  ...
#
#    Customer_Loyalty_Program_Member Purchase_Intent  Shipping_Preference  \
# 0                            False      Need-based        No Preference
#
#    Time_to_Decision  Month  Year Day_Name  Day  Hour Weekday
# 0                 2      3  2024   Friday    1     0  Friday
#
# [1 rows x 34 columns]

# %% [markdown]
# # Income Level , Education Level Vs Purchase Amount

# %%
df.groupby(["Income_Level", "Education_Level"])["Purchase_Amount"].sum()
# Out:
# Income_Level  Education_Level
# High          Bachelor's         49924
#               High School        47969
#               Master's           43732
# Middle        Bachelor's         46689
#               High School        42629
#               Master's           43618
# Name: Purchase_Amount, dtype: int64

# %%
plt.figure(figsize=(11,4))
income=df.groupby(["Income_Level", "Education_Level"])["Purchase_Amount"].sum()
income.plot(kind="bar",width=0.4,edgecolor="blue",linewidth=2,color="brown")
plt.title("Income Level And Education level Vs Purchase Amount In USD")
plt.xlabel("Income Level And Education Level")
plt.ylabel("Total Purchase Amount")
plt.show()

# %%
df.groupby(["Purchase_Channel", "Payment_Method"])["Purchase_Amount"].sum()
# Out:
# Purchase_Channel  Payment_Method
# In-Store          Cash              15523
#                   Credit Card       15540
#                   Debit Card        18198
#                   Other             21714
#                   PayPal            17158
# Mixed             Cash              16867
#                   Credit Card       21288
#                   Debit Card        17373
#                   Other             16944
#                   PayPal            22518
# Online            Cash              17589
#                   Credit Card       15757
#                   Debit Card        17875
#                   Other             19037
#                   PayPal            21180
# Name: Purchase_Amount, dtype: int64

# %%
plt.figure(figsize=(11,4))
income=df.groupby(["Purchase_Channel", "Payment_Method"])["Purchase_Amount"].sum()
income.plot(kind="bar", color="orange",width=0.6,edgecolor="green",linewidth=2)
plt.title("Purchase Channel And Payment Method Vs Purchase Amount In USD")
plt.xlabel("Purchase Channel And Payment Method")
plt.ylabel("Total Purchase Amount")
plt.show()

# %% [markdown]
# # Customer Purchase Behavior Analysis 📊![download.jpeg](data:image/jpeg;base64,...)
#
#
#
#
# 📌 Project Overview
# This project analyzes customer purchase behavior using a dataset of 1000 customers. The goal is to uncover valuable insights that help businesses optimize marketing strategies, improve customer retention, and increase sales.
#
#
# 🔍 Key Insights & Business Impact
# 1️⃣ High-Value Customers (Top Spenders 💰)
# Top spenders are middle-aged professionals with high-income levels.
#
# Business Action: Target high-value customers with personalized offers & exclusive deals.
#
# 2️⃣ Customer Loyalty & Retention 🔄
# Customers with higher Brand Loyalty Scores spend more.
#
# Loyalty program members tend to spend significantly more than non-members.
#
# Business Action: Expand customer loyalty programs & reward repeat buyers.
#
# 3️⃣ Best Time for Marketing Campaigns 🕒
# Most purchases happen between 6 PM - 9 PM & on weekends.
#
# Business Action: Schedule ads & promotions during peak shopping hours.
#
# 4️⃣ Discounts & Pricing Strategy 🎯
# Discount-sensitive customers spend less per purchase but buy more frequently.
#
# Business Action: Offer targeted discounts to encourage higher total spending.
#
# 5️⃣ Shopping Channel & Device Preference 📱💻
# Online shopping is more preferred than Offline purchases.
#
# Business Action: Invest in digital marketing & enhance online shopping experience.
